# %%
from matplotlib import pyplot
import numpy
import sympy

# %% [markdown]
# ## Overview
#
# The figures in this chapter represent the movement of two populations ($\mathcal{P}^\mu$ and $\mathcal{P}^\nu$) between two sections of one city (sections 1 and 2).  The two populations have internal agglomeration trends κ (the tendency for a population to want to live with itself) and segregation trends (the tendency for a population to not want to live with the other population), which can be either symmetric or asymmetric.  The figures below explore a range of possibilities by varying the agglomeration and segregation trends.

# %% [markdown]
# ### Figure 4.1
#
# In this figure, we have a weak internal agglomeration trend and a weak reciprocal segregation trend.  All fluxlines approach the origin, so the homogeneous mixture of populations $\mathcal{P}^\mu$ and $\mathcal{P}^\nu$ is stable.

# %%
N = 100                                
x_start, x_end = -1.0, 1.0
y_start, y_end = -1.0, 1.0
x = numpy.linspace(x_start, x_end, N)
y = numpy.linspace(y_start, y_end, N)

X, Y = numpy.meshgrid(x, y)

κ_μμ = 0.5
κ_νν = 0.5
κ_μν = -0.2
κ_νμ = -0.2

dx = numpy.sinh(κ_μμ * X + κ_μν * Y) - X * numpy.cosh(κ_μμ * X + κ_μν * Y)
dy = numpy.sinh(κ_νμ * X + κ_νν * Y) - Y * numpy.cosh(κ_νμ * X + κ_νν * Y)

# %matplotlib inline
pyplot.figure(figsize=(10,10))
pyplot.title('Figure 4.1 (a)')
pyplot.xlabel('x(τ)', fontsize = 14)
pyplot.ylabel('y(τ)', fontsize = 14)
pyplot.xlim(x_start, x_end)
pyplot.ylim(y_start, y_end)
pyplot.streamplot(X, Y, dx, dy, linewidth = 1, density = 2)

# %% [markdown]
# ### Figure 4.2
#
# In this figure, we have a moderate internal agglomeration trend and a strong reciprocal segregation trend.  All fluxlines approach one of two equilibrium points in the second and fourth quadrants, so the homogeneous mixture of populations $\mathcal{P}^\mu$ and $\mathcal{P}^\nu$ is unstable, and the population will self-segregate into two ghettos.

# %%
N = 100                                
x_start, x_end = -1.0, 1.0
y_start, y_end = -1.0, 1.0
x = numpy.linspace(x_start, x_end, N)
y = numpy.linspace(y_start, y_end, N)

X, Y = numpy.meshgrid(x, y)

κ_μμ = 0.5
κ_νν = 0.5
κ_μν = 1
κ_νμ = 1

#dx = (κ_μμ - 1) * X + κ_μν * Y
#dy = κ_νμ * X + (κ_νν - 1) * X

dx = numpy.sinh(κ_μμ * X + κ_μν * Y) - X * numpy.cosh(κ_μμ * X + κ_μν * Y)
dy = numpy.sinh(κ_νμ * X + κ_νν * Y) - Y * numpy.cosh(κ_νμ * X + κ_νν * Y)

# %matplotlib inline
pyplot.figure(figsize=(10,10))
pyplot.title('Figure 4.2 (a)')
pyplot.xlabel('x(τ)', fontsize = 14)
pyplot.ylabel('y(τ)', fontsize = 14)
pyplot.xlim(x_start, x_end)
pyplot.ylim(y_start, y_end)
pyplot.streamplot(X, Y, dx, dy, linewidth = 1, density = 2)

# %% [markdown]
# ### Figure 4.3
#
# In this figure, we have a moderate internal agglomeration trend and a strong asymmetric interaction.  All fluxlines spiral into the center point, so the homogeneous mixture of populations $\mathcal{P}^\mu$ and $\mathcal{P}^\nu$ is stable, and the population will slowly become homogeneous.

# %%
N = 100                                
x_start, x_end = -1.0, 1.0
y_start, y_end = -1.0, 1.0
x = numpy.linspace(x_start, x_end, N)
y = numpy.linspace(y_start, y_end, N)

X, Y = numpy.meshgrid(x, y)

κ_μμ = 0.5
κ_νν = 0.5
κ_μν = -1
κ_νμ = 1

#dx = (κ_μμ - 1) * X + κ_μν * Y
#dy = κ_νμ * X + (κ_νν - 1) * X

dx = numpy.sinh(κ_μμ * X + κ_μν * Y) - X * numpy.cosh(κ_μμ * X + κ_μν * Y)
dy = numpy.sinh(κ_νμ * X + κ_νν * Y) - Y * numpy.cosh(κ_νμ * X + κ_νν * Y)

# %matplotlib inline
pyplot.figure(figsize=(10,10))
pyplot.title('Figure 4.3 (a)')
pyplot.xlabel('x(τ)', fontsize = 14)
pyplot.ylabel('y(τ)', fontsize = 14)
pyplot.xlim(x_start, x_end)
pyplot.ylim(y_start, y_end)
pyplot.streamplot(X, Y, dx, dy, linewidth = 1, density = 2)

# %% [markdown]
# ### Figure 4.4
#
# In this figure, we have a very strong internal agglomeration trend and a strong asymmetric interaction.  All fluxlines spiral approach a limit cycle, and so both populations will continue to move from section to section indefinitely.

# %%
N = 100                                
x_start, x_end = -1.0, 1.0
y_start, y_end = -1.0, 1.0
x = numpy.linspace(x_start, x_end, N)
y = numpy.linspace(y_start, y_end, N)

X, Y = numpy.meshgrid(x, y)

κ_μμ = 1.2
κ_νν = 1.2
κ_μν = -1
κ_νμ = +1

#dx = (κ_μμ - 1) * X + κ_μν * Y
#dy = κ_νμ * X + (κ_νν - 1) * X

dx = numpy.sinh(κ_μμ * X + κ_μν * Y) - X * numpy.cosh(κ_μμ * X + κ_μν * Y)
dy = numpy.sinh(κ_νμ * X + κ_νν * Y) - Y * numpy.cosh(κ_νμ * X + κ_νν * Y)

# %matplotlib inline
pyplot.figure(figsize=(10,10))
pyplot.title('Figure 4.4 (a)')
pyplot.xlabel('x(τ)', fontsize = 14)
pyplot.ylabel('y(τ)', fontsize = 14)
pyplot.xlim(x_start, x_end)
pyplot.ylim(y_start, y_end)
pyplot.streamplot(X, Y, dx, dy, linewidth = 1, density = 1)
